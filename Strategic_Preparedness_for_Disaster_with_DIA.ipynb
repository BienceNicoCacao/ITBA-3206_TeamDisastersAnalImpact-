# %% [markdown]
# <a href="https://colab.research.google.com/github/BienceNicoCacao/ITBA-3206_TheEcoWarriors/blob/master/Strategic_Preparedness_for_Disaster_with_DIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://github.com/BienceNicoCacao/ITBA-3206_TheEcoWarriors/blob/master/images/world.jpg?raw=1" width="2000" height="400">

# %% [markdown]
# # 🌳**Strategic Preparedness for Disaster with DIA**🌳
#
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import io
from matplotlib import pyplot as plt
from google.colab import data_table

# %% [markdown]
# ## **Dataset of Disasters**
#
#
# ---

# %%
url = 'https://raw.githubusercontent.com/BienceNicoCacao/ITBA-3206_TheEcoWarriors/master/philippines_2020-significant-events1.csv'

# %%
df= pd.read_csv(url)
df.head(1621)
# Out:
#            Type of incident  Year Date occurred  \
# 0     Taal Volcano Eruption  2020     12-Jan-20
# 1     Taal Volcano Eruption  2020     12-Jan-20
# 2     Taal Volcano Eruption  2020     12-Jan-20
# 3     Taal Volcano Eruption  2020     12-Jan-20
# 4     Taal Volcano Eruption  2020     12-Jan-20
# ...                     ...   ...           ...
# 1615   Earthquake (6.6 mag)  2020     18-Aug-20
# 1616   Earthquake (6.6 mag)  2020     18-Aug-20
# 1617   Earthquake (6.6 mag)  2020     18-Aug-20
# 1618   Earthquake (6.6 mag)  2020     18-Aug-20
# 1619   Earthquake (6.2 mag)  2020     16-Dec-20
#
#                              Region  \
# 0     NATIONAL CAPITAL REGION (NCR)
# 1     NATIONAL CAPITAL REGION (NCR)
# 2     NATIONAL CAPITAL REGION (NCR)
# 3     NATIONAL CAPITAL REGION (NCR)
# 4     NATIONAL CAPITAL REGION (NCR)
# ...                             ...
# 1615        REGION V (BICOL REGION)
# 1616        REGION V (BICOL REGION)
# 1617        REGION V (BICOL REGION)
# ...

# %% [markdown]
# ## **Data Cleanning**
#
# ---
#
# ##### **_Dropping unnecessary columns_**

# %%
df= pd.DataFrame(df)
df.drop(['Evacuation (Cummulative)', 
         'Evacuation (Now)'], axis = 1, inplace=True)
display(df)
# Out:
#            Type of incident  Year Date occurred  \
# 0     Taal Volcano Eruption  2020     12-Jan-20
# 1     Taal Volcano Eruption  2020     12-Jan-20
# 2     Taal Volcano Eruption  2020     12-Jan-20
# 3     Taal Volcano Eruption  2020     12-Jan-20
# 4     Taal Volcano Eruption  2020     12-Jan-20
# ...                     ...   ...           ...
# 1615   Earthquake (6.6 mag)  2020     18-Aug-20
# 1616   Earthquake (6.6 mag)  2020     18-Aug-20
# 1617   Earthquake (6.6 mag)  2020     18-Aug-20
# 1618   Earthquake (6.6 mag)  2020     18-Aug-20
# 1619   Earthquake (6.2 mag)  2020     16-Dec-20
#
#                              Region  \
# 0     NATIONAL CAPITAL REGION (NCR)
# 1     NATIONAL CAPITAL REGION (NCR)
# 2     NATIONAL CAPITAL REGION (NCR)
# 3     NATIONAL CAPITAL REGION (NCR)
# 4     NATIONAL CAPITAL REGION (NCR)
# ...                             ...
# 1615        REGION V (BICOL REGION)
# 1616        REGION V (BICOL REGION)
# 1617        REGION V (BICOL REGION)
# ...

# %% [markdown]
# ##### **_Check nulls in column_**

# %%
df.isnull().sum()
# Out:
# Type of incident                   0
# Year                               0
# Date occurred                      0
# Region                             0
# Province                           0
# City_Municipality                  0
# Affected_Brgys                     0
# Affected_FAM                       0
# Affected_PERs                      0
# INSIDE_ECs_FAM\n(Cummulative)      0
# INSIDE_ECs_FAM\n(Now)              0
# INSIDE_ECs_PERs\n(Cummulative)     0
# INSIDE_ECs_PERs\n(Now)             0
# OUTSIDE_ECs_FAM\n(Cummulative)     0
# OUTSIDE_ECs_FAM\n(Now)             0
# OUTSIDE_ECs_PERs\n(Cummulative)    0
# OUTSIDE_ECs_PERs\n(Now)            0
# Destroyed houses                   0
# Partially damaged houses           0
# Total                              0
# Region Code                        0
# Province Code                      0
# City_Municipality Code             0
# dtype: int64

# %% [markdown]
# ##### **_Removing Duplicates_**

# %%
dupes = df.duplicated()
print(dupes[dupes == True])

df.drop_duplicates(inplace=True)
df.head(400)
# Out:
# Series([], dtype: bool)
#           Type of incident  Year Date occurred                         Region  \
# 0    Taal Volcano Eruption  2020     12-Jan-20  NATIONAL CAPITAL REGION (NCR)
# 1    Taal Volcano Eruption  2020     12-Jan-20  NATIONAL CAPITAL REGION (NCR)
# 2    Taal Volcano Eruption  2020     12-Jan-20  NATIONAL CAPITAL REGION (NCR)
# 3    Taal Volcano Eruption  2020     12-Jan-20  NATIONAL CAPITAL REGION (NCR)
# 4    Taal Volcano Eruption  2020     12-Jan-20  NATIONAL CAPITAL REGION (NCR)
# ..                     ...   ...           ...                            ...
# 395     TY MOLAVE (Quinta)  2020     23-Oct-20       REGION IV-A (CALABARZON)
# 396     TY MOLAVE (Quinta)  2020     23-Oct-20       REGION IV-A (CALABARZON)
# 397     TY MOLAVE (Quinta)  2020     23-Oct-20       REGION IV-A (CALABARZON)
# 398     TY MOLAVE (Quinta)  2020     23-Oct-20       REGION IV-A (CALABARZON)
# 399     TY MOLAVE (Quinta)  2020     23-Oct-20       REGION IV-A (CALABARZON)
#
# ...

# %% [markdown]
# ## **Data Visualization**
#
# ---

# %%
import plotly.graph_objects as go

labels = ['Taal Volcano Eruption','Earthquake (6.6 mag)','TY MOLAVE (Quinta)']
values = [4500, 2500, 1053]

# pull is given as a fraction of the pie radius
fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0, 0, 0.2])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
sns.lineplot(data=df, x='Year', y='Affected_Brgys', hue='Type of incident')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [4500, 2500, 1053]
labels = ['Taal Volcano Eruption','Earthquake (6.6 mag)','TY MOLAVE (Quinta)']

colors = sns.color_palette('pastel')[0:5]

plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
